# %%
import pandas as pd
import streamlit as st
import sqlite3 as sq
import datetime
db = 'mms_master.sqlite'


disp_cols = ['ship_name', 'dt_ocurred', 'target_dt', 'done_dt', 'ser_no', 'nc_detail', 'est_cause_ship',
                 'init_action_ship', 'init_action_ship_dt',
                 'final_action_ship', 'final_action_ship_dt', 'co_eval',
                 'reason_rc', 'corr_action', 'rpt_by', 'insp_by', 'insp_detail', 'update_by', 'update_dt',
                 'ext_dt', 'ext_rsn', 'req_num', 'ext_cmnt', 'sys_code', 'eq_code']
conn= sq.connect(db)
df_DRS = pd.read_sql_query(f'select * from drsend', conn)
df_vsl= pd.read_sql_query(f'select * from vessels', conn)
df_DRS =df_DRS.loc(df_DRS(['DRS_ID'].str.beginswith('T' --------+++++++

display(df_DRS)
# Out:
#                        DRS_ID  dt_ocurred        ser_no    rpt_by   moge  \
# 0     TP201700520200707032116  2020-06-18  OIN-2020-020  F Vessel  Fmoge
# 1     TP201700520200707033132  2020-06-21  OIN-2020-021   G Other  Gmoge
# 2     TP201700520200707034142  2020-06-25  OIN-2020-022   G Other  Gmoge
# 3     TP201700520200707071139  2020-06-28  OIN-2020-023  F Vessel  Fmoge
# 4     TP201700520200707072318  2020-06-19  OIN-2020-024  F Vessel  Fmoge
# ...                       ...         ...           ...       ...    ...
# 8503  TP202000620220331212136  2022-03-30   SMD-2022-09     C MMS  Cmoge
# 8504  TP202000620220331212137  2022-03-30  SMD-2022-010     C MMS  Cmoge
# 8505  TP202000620220331212138  2022-03-30  SMD-2022-011     C MMS  Cmoge
# 8506  TP202000620220331212139  2022-03-30  SMD-2022-012     C MMS  Cmoge
# 8507  TP202000620220331212140  2022-03-30  SMD-2022-013     C MMS  Cmoge
#
#        hoge    insp_by           insp_detail                      def_code  \
# 0     Fhoge  F1 MASTER  VIRENDRA VISHWAKARMA     LSA Life Saving Appliance
# 1     Ghoge  G4 OTHERS            ALOK DUBEY                     OTR Other
# 2     Ghoge  G4 OTHERS            ALOK DUBEY                     OTR Other
# 3     Fhoge  F2 OTHERS   HEMANT PRABHUKHADPE  PAE Piping and Valves in E/R
# 4     Fhoge  F2 OTHERS          ANAND MISHRA   FFA Fire Fighting Appliance
# ...     ...        ...                   ...                           ...
# 8503  Choge    C1 S.I.   Rajesh Kunar Prasad                       MMS MMS
# 8504  Choge    C1 S.I.   Rajesh Kunar Prasad                       MMS MMS
# 8505  Choge    C1 S.I.   Rajesh Kunar Prasad                       MMS MMS
# 8506  Choge    C1 S.I.   Rajesh Kunar Prasad                       MMS MMS
# 8507  Choge    C1 S.I.   Rajesh Kunar Prasad                       MMS MMS
#
#      def_short  ... PSC_info2mmstpmgmt_dt PSC_sndr_offimport  \
# 0          LSA  ...
# 1          OTR  ...
# 2          OTR  ...
# 3          PAE  ...
# 4          FFA  ...
# ...        ...  ...                   ...                ...
# 8503       MMS  ...
# 8504       MMS  ...
# 8505       MMS  ...
# 8506       MMS  ...
# 8507       MMS  ...
#
#      PSC_sndr_offimport_dt VET_oilmaj VET_oilmaj_co VET_offattnd VET_risk  \
# 0
# 1
# 2
# 3
# 4
# ...                    ...        ...           ...          ...      ...
# 8503
# 8504
# 8505
# 8506
# 8507
#
#      VET_repupload VET_repfinalby VET_Q88upload
# 0
# 1
# 2
# 3
# 4
# ...            ...            ...           ...
# 8503
# 8504
# 8505
# 8506
# 8507
#
# [8508 rows x 100 columns]
